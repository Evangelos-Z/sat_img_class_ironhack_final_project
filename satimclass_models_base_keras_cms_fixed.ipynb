# %% [markdown]
# # <a id="0"></a> Table of Contents
# 6. [Importing Libraries](#6)
# 7. [Instantiating Directories & Importing Datasets](#7)
# 8. [Keras CNN](#8)<br>
#     8.1. [Universal Settings - Image Pre-processing & Augmentation](#8.1)<br>
#     8.2. [Baselince Model - Imbalanced Set](#8.2)<br>
#     8.3. [Running Model With Balanced Set](#8.3)<br>
#     8.4. [Model Optimization](#8.4)

# %% [markdown]
# <div class="alert alert-block alert-info"><b>Note:</b>See [TITLE](href) for an overview of the data processing that took place before.</div>

# %% [markdown]
# # <a id="6"></a> <font color = "lightseagreen">6. Importing Libraries<font>

# %%
# Basic Libraries
import pandas as pd
import numpy as np
import sys

# Path & File Management
import os
import shutil

# Visualization Libraries
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
import seaborn as sns

# Image Manipulation/Processing
from PIL import Image

# CNNs, Classification, Dataset Access, Image Augmentation
import tensorflow as tf
from tensorflow import keras # deep learning and neural networks
from tensorflow.keras import layers # layers for neural networks
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.utils import image_dataset_from_directory
from tensorflow.keras.preprocessing import image

# Evaluation Metrics
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# Settings
import warnings
import time

# Notifications
import winsound

# %%
tf.config.experimental.list_physical_devices("GPU")
# Out:
# []

# %%
# Session parameters
warnings.filterwarnings("ignore")
np.set_printoptions(threshold=sys.maxsize)

# Function to be notified when cell is done executing
def cell_done():
    freq = 500
    dur = 50
    for i in range(0, 10):   
        winsound.Beep(freq, dur)   
        freq-= 20
        dur+= 50

# %% [markdown]
# # <a id=7></a><font color = "lightseagreen">7. Instantiating Directories & Importing Dataframes<font>

# %%
# Loading all dirs and dfs related to the dataset
# Paths for imbalanced dataset
data_path = os.path.join(os.getcwd(), "data")
imbalanced_test_dir = os.path.join(data_path, "test")

# Paths for balanced dataset
data_balance = os.path.join(os.getcwd(), "data_balance")
balanced_test_dir = os.path.join(data_balance, "test")

# %% [markdown]
# # <a id = 8></a><font color="lightseagreen">8. Keras CNN<font>

# %%
# Code copied from @isi_mube and @sabinagio (Github)
# Function to generate keras CNN model structure
def make_model(input_shape): 
    inputs = keras.Input(shape=input_shape)

    x = layers.Conv2D(32, (3, 3), activation='relu')(inputs)
    x = layers.MaxPooling2D((2, 2))(x)

    x = layers.Conv2D(64, (3, 3), activation='relu')(x)
    x = layers.MaxPooling2D((2, 2))(x)

    x = layers.Conv2D(128, (1, 1), activation='relu')(x)
    x = layers.MaxPooling2D((2, 2))(x)

    x = layers.Conv2D(256, (2, 2), activation='relu')(x)
    x = layers.MaxPooling2D((2, 2))(x)

    x = layers.Flatten()(x)
    x = layers.Dense(512, activation='relu')(x)
    x = layers.Dense(256, activation='relu')(x)
    x = layers.Dense(4, activation='softmax')(x)  # 4 categories --> 4 dense need to find out how these things work exactly
                                                  # FROM ISIS'S CYTOLOGY INDEX: softmax ---> no clue why

    return keras.Model(inputs, x)

# %% [markdown]
# ## <a id = 8.1></a><font color="lightseagreen">8.1 Universal Settings - Image Pre-processing & Augmentation<font>

# %%
# Comparison in the accuracy scores and loss of models run with 64x64, 128x128 and 256x256 res showed that 256x256 had better overall scores
img_height = 256 
img_width = 256
image_size = (img_height, img_width)

# %%
# Image augmentation will increase the number of images on the fly by applying rescaling, changing brightness,
# adding distortion etc. as the model runs, and thus train the model on multiple potential ways of viewing an image
datagen = ImageDataGenerator(
    rescale=1.0/255,  # Important for normalization of input and avoiding larger images having greater weights
    brightness_range=[.6, 1.3],  # Value randomly selected from range between values of list, which were arbitrarily selected
    channel_shift_range=0.2,  # Channel shift is used to introduce the color augmentation in the dataset so as to make the model learn color based features irrespective of its saturation value.https://stackoverflow.com/questions/70515757/difference-between-channel-shift-range-and-brightness-range-in-imagedatagenerato 
    zoom_range=0.4,
)

test_datagen = ImageDataGenerator(rescale=1.0 / 255.0)

# %%
# Picking minibatches of relatively medium proportions to start with for the comparison between imbalanced and balanced data
batch_size = 128

# %% [markdown]
# ## <a id = 8.2><font color="lightseagreen">8.2 Baseline Model - Imbalanced Set<font></a>

# %% [markdown]
# ### <font color="lightseagreen">- Setting Up and Running Model<font>

# %%
# The model requires that the train and validation data exist in directories dependent on their categories,
# so train and valid directories, along with their nested subdirectories will be will be used
train_dir_imb = os.path.join(data_path, "train")
val_dir_imb = os.path.join(data_path, "valid")

# %%
# Loading training data
train_ds_imb = datagen.flow_from_directory(
    train_dir_imb,
    seed=400,  # just has to stay the same, equivalent of random_state
    target_size=image_size,
    batch_size=batch_size,  # how many images per step
    class_mode="categorical"  # for multi-class
)

# Loading validation data
val_ds_imb = datagen.flow_from_directory(
    val_dir_imb,
    seed=400,
    target_size=image_size,
    batch_size=batch_size,
    class_mode="categorical"
)

test_generator = test_datagen.flow_from_directory(
    imbalanced_test_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False  # Important: Do not shuffle the test data
)
# Out:
# Found 4474 images belonging to 4 classes.
# Found 559 images belonging to 4 classes.
# Found 559 images belonging to 1 classes.

# %%
# Defining model
model = make_model(input_shape=image_size + (3,))

# %%
# Compiling model
model.compile(
    optimizer=keras.optimizers.Adamax(learning_rate=0.001),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
# Defining step sizes as exact divisors of the train and test set respectively. This way the model will run through
# the entire set each epoch
step_size_train = train_ds_imb.n//train_ds_imb.batch_size
step_size_val = val_ds_imb.n//val_ds_imb.batch_size

# Setting up directory to store versions of the model. The best one will be picked and reloaded
callbacks = [
    keras.callbacks.ModelCheckpoint("data/epochs_imbalanced_data/save_at_{epoch}.keras")
]

# %% [markdown]
# ### <font color="lightseagreen">- Training & Evaluation<font>

# %%
# And finally training the model
hist = model.fit(
    train_ds_imb, 
    epochs=50,
    steps_per_epoch = step_size_train,
    validation_data=val_ds_imb,
    validation_steps = step_size_val,
    callbacks = callbacks
)

cell_done()
# Out:
# Epoch 1/50
# 34/34 [==============================] - 170s 5s/step - loss: 0.8408 - accuracy: 0.5759 - val_loss: 0.6457 - val_accuracy: 0.6309
# Epoch 2/50
# 34/34 [==============================] - 176s 5s/step - loss: 0.4699 - accuracy: 0.7835 - val_loss: 0.3963 - val_accuracy: 0.8145
# Epoch 3/50
# 34/34 [==============================] - 167s 5s/step - loss: 0.3642 - accuracy: 0.8495 - val_loss: 0.3422 - val_accuracy: 0.8691
# Epoch 4/50
# 34/34 [==============================] - 168s 5s/step - loss: 0.3399 - accuracy: 0.8599 - val_loss: 0.3328 - val_accuracy: 0.8496
# Epoch 5/50
# 34/34 [==============================] - 168s 5s/step - loss: 0.3446 - accuracy: 0.8622 - val_loss: 0.4250 - val_accuracy: 0.7891
# Epoch 6/50
# 34/34 [==============================] - 166s 5s/step - loss: 0.3364 - accuracy: 0.8578 - val_loss: 0.3138 - val_accuracy: 0.8711
# Epoch 7/50
# 34/34 [==============================] - 167s 5s/step - loss: 0.3121 - accuracy: 0.8741 - val_loss: 0.3105 - val_accuracy: 0.8691
# Epoch 8/50
# 34/34 [==============================] - 167s 5s/step - loss: 0.2945 - accuracy: 0.8810 - val_loss: 0.3220 - val_accuracy: 0.8691
# Epoch 9/50
# 34/34 [==============================] - 167s 5s/step - loss: 0.3055 - accuracy: 0.8785 - val_loss: 0.3075 - val_accuracy: 0.8770
# Epoch 10/50
# 34/34 [==============================] - 168s 5s/step - loss: 0.3162 - accuracy: 0.8663 - val_loss: 0.3094 - val_accuracy: 0.8672
# Epoch 11/50
# 34/34 [==============================] - 176s 5s/step - loss: 0.2852 - accuracy: 0.8843 - val_loss: 0.3753 - val_accuracy: 0.8496
# Epoch 12/50
# 34/34 [==============================] - 166s 5s/step - loss: 0.2878 - accuracy: 0.8796 - val_loss: 0.3124 - val_accuracy: 0.8555
# Epoch 13/50
# 34/34 [==============================] - 166s 5s/step - loss: 0.2608 - accuracy: 0.8988 - val_loss: 0.2995 - val_accuracy: 0.8594
# Epoch 14/50
# 34/34 [==============================] - 166s 5s/step - loss: 0.2880 - accuracy: 0.8771 - val_loss: 0.2582 - val_accuracy: 0.8965
# Epoch 15/50
# 34/34 [==============================] - 165s 5s/step - loss: 0.2440 - accuracy: 0.9027 - val_loss: 0.2400 - val_accuracy: 0.8945
# Epoch 16/50
# 34/34 [==============================] - 166s 5s/step - loss: 0.2400 - accuracy: 0.9043 - val_loss: 0.2477 - val_accuracy: 0.8965
# Epoch 17/50
# 34/34 [==============================] - 166s 5s/step - loss: 0.2369 - accuracy: 0.9073 - val_loss: 0.2299 - val_accuracy: 0.9121
# Epoch 18/50
# 34/34 [==============================] - 165s 5s/step - loss: 0.2306 - accuracy: 0.9128 - val_loss: 0.2046 - val_accuracy: 0.9160
# Epoch 19/50
# 34/34 [==============================] - 166s 5s/step - loss: 0.2380 - accuracy: 0.8999 - val_loss: 0.2768 - val_accuracy: 0.8809
# Epoch 20/50
# 34/34 [==============================] - 165s 5s/step - loss: 0.2361 - accuracy: 0.9015 - val_loss: 0.2551 - val_accuracy: 0.8945
# Epoch 21/50
# 34/34 [==============================] - 166s 5s/step - loss: 0.2207 - accuracy: 0.9093 - val_loss: 0.2315 - val_accuracy: 0.8926
# Epoch 22/50
# 34/34 [==============================] - 166s 5s/step - loss: 0.2311 - accuracy: 0.9073 - val_loss: 0.2012 - val_accuracy: 0.9297
# Epoch 23/50
# 34/34 [==============================] - 166s 5s/step - loss: 0.2329 - accuracy: 0.9061 - val_loss: 0.2093 - val_accuracy: 0.9199
# Epoch 24/50
# 34/34 [==============================] - 166s 5s/step - loss: 0.1822 - accuracy: 0.9328 - val_loss: 0.2327 - val_accuracy: 0.8965
# Epoch 25/50
# 34/34 [==============================] - 166s 5s/step - loss: 0.2041 - accuracy: 0.9179 - val_loss: 0.2349 - val_accuracy: 0.9004
# Epoch 26/50
# 34/34 [==============================] - 166s 5s/step - loss: 0.1945 - accuracy: 0.9229 - val_loss: 0.1764 - val_accuracy: 0.9297
# Epoch 27/50
# 34/34 [==============================] - 167s 5s/step - loss: 0.1642 - accuracy: 0.9406 - val_loss: 0.2041 - val_accuracy: 0.9219
# Epoch 28/50
# 34/34 [==============================] - 166s 5s/step - loss: 0.1656 - accuracy: 0.9351 - val_loss: 0.1859 - val_accuracy: 0.9355
# Epoch 29/50
# 34/34 [==============================] - 166s 5s/step - loss: 0.1627 - accuracy: 0.9376 - val_loss: 0.1843 - val_accuracy: 0.9258
# Epoch 30/50
# 34/34 [==============================] - 166s 5s/step - loss: 0.1414 - accuracy: 0.9443 - val_loss: 0.1750 - val_accuracy: 0.9258
# Epoch 31/50
# 34/34 [==============================] - 166s 5s/step - loss: 0.1620 - accuracy: 0.9356 - val_loss: 0.1825 - val_accuracy: 0.9219
# Epoch 32/50
# 34/34 [==============================] - 166s 5s/step - loss: 0.1346 - accuracy: 0.9503 - val_loss: 0.1407 - val_accuracy: 0.9434
# Epoch 33/50
# 34/34 [==============================] - 166s 5s/step - loss: 0.1371 - accuracy: 0.9471 - val_loss: 0.1772 - val_accuracy: 0.9199
# Epoch 34/50
# 34/34 [==============================] - 165s 5s/step - loss: 0.1504 - accuracy: 0.9418 - val_loss: 0.2223 - val_accuracy: 0.9238
# Epoch 35/50
# 34/34 [==============================] - 166s 5s/step - loss: 0.1619 - accuracy: 0.9360 - val_loss: 0.1956 - val_accuracy: 0.9238
# Epoch 36/50
# 34/34 [==============================] - 165s 5s/step - loss: 0.1537 - accuracy: 0.9383 - val_loss: 0.1864 - val_accuracy: 0.9336
# Epoch 37/50
# 34/34 [==============================] - 166s 5s/step - loss: 0.1275 - accuracy: 0.9565 - val_loss: 0.1770 - val_accuracy: 0.9395
# Epoch 38/50
# 34/34 [==============================] - 166s 5s/step - loss: 0.1373 - accuracy: 0.9496 - val_loss: 0.4406 - val_accuracy: 0.8398
# Epoch 39/50
# 34/34 [==============================] - 166s 5s/step - loss: 0.1660 - accuracy: 0.9337 - val_loss: 0.1356 - val_accuracy: 0.9551
# Epoch 40/50
# 34/34 [==============================] - 165s 5s/step - loss: 0.1181 - accuracy: 0.9581 - val_loss: 0.1243 - val_accuracy: 0.9590
# Epoch 41/50
# 34/34 [==============================] - 165s 5s/step - loss: 0.1065 - accuracy: 0.9625 - val_loss: 0.1252 - val_accuracy: 0.9668
# Epoch 42/50
# 34/34 [==============================] - 166s 5s/step - loss: 0.1217 - accuracy: 0.9588 - val_loss: 0.1176 - val_accuracy: 0.9629
# Epoch 43/50
# 34/34 [==============================] - 166s 5s/step - loss: 0.1223 - accuracy: 0.9542 - val_loss: 0.1052 - val_accuracy: 0.9648
# Epoch 44/50
# 34/34 [==============================] - 166s 5s/step - loss: 0.1039 - accuracy: 0.9650 - val_loss: 0.1618 - val_accuracy: 0.9316
# Epoch 45/50
# 34/34 [==============================] - 165s 5s/step - loss: 0.1706 - accuracy: 0.9370 - val_loss: 0.1602 - val_accuracy: 0.9492
# Epoch 46/50
# 34/34 [==============================] - 166s 5s/step - loss: 0.1423 - accuracy: 0.9485 - val_loss: 0.1043 - val_accuracy: 0.9629
# Epoch 47/50
# 34/34 [==============================] - 167s 5s/step - loss: 0.0920 - accuracy: 0.9694 - val_loss: 0.1133 - val_accuracy: 0.9648
# Epoch 48/50
# 34/34 [==============================] - 167s 5s/step - loss: 0.0896 - accuracy: 0.9712 - val_loss: 0.1304 - val_accuracy: 0.9551
# Epoch 49/50
# 34/34 [==============================] - 166s 5s/step - loss: 0.1156 - accuracy: 0.9581 - val_loss: 0.1315 - val_accuracy: 0.9648
# Epoch 50/50
# 34/34 [==============================] - 169s 5s/step - loss: 0.0992 - accuracy: 0.9666 - val_loss: 0.1316 - val_accuracy: 0.9668

# %%
# Saving scores for easy access
imbalanced_hist_df = pd.DataFrame(hist.history)
imbalanced_hist_df.to_csv("data/base_imbalanced_scores.csv", index = 0)

# %%
# Plotting accuracy from model history
fig = plt.figure(figsize = (7,5))
plt.plot(hist.history["accuracy"], color="rebeccapurple", label="accuracy")
plt.plot(hist.history["val_accuracy"], color="springgreen", label="val_accuracy")
plt.ylim(0,1)
fig.suptitle("Accuracy - Base - Imbalanced", fontsize=17)
plt.legend(loc="upper left")
plt.show()

# %%
# Plotting loss from history
fig = plt.figure(figsize = (7,5))
plt.plot(hist.history["loss"], color="rebeccapurple", label="loss")
plt.plot(hist.history["val_loss"], color="springgreen", label="val_loss")
plt.ylim(0,1)
fig.suptitle("Loss - Base - Imbalanced", fontsize=17)
plt.legend(loc="upper right")
plt.show()

# %%
# Epoch 46 has provided the best relative scores
checkpoint_path_base_imb = os.path.join(data_path, "epochs_imbalanced_data", "save_at_46.keras")
model.load_weights(checkpoint_path_base_imb)
# Out:
# WARNING:absl:Skipping variable loading for optimizer 'Adamax', because it has 1 variables whereas the saved optimizer has 29 variables.

# %%
# Creating customized colormap for the confusion matrix
colors = [[0/255, 250/255, 154/255], [102/255,51/255,153/255]] # first color is MediumSpringGreen, last is RebeccaPurple
cm_funkyish = LinearSegmentedColormap.from_list(
        "Custom", colors, N=256, gamma = 2)
# mat = np.indices((10,10))[1]
# plt.imshow(mat, cmap=cm_funky)
# plt.show()

# %% [markdown]
# <h3 style = "color:lightseagreen">- Testing Against Unseen Data (test set)</h3>

# %%
# Function written partially by ChatGPT
# It serves to turn images in the specified directory to arrays, which will then be appended to a list of arrays
def load_test_data(test_directory, target_size):
    image_arrays = []
    
    # turning images to arrays
    for filename in os.listdir(test_directory):
        img_path = os.path.join(test_directory, filename)
        img = load_img(img_path, target_size=target_size)
        img_array = img_to_array(img)
        
        image_arrays.append(img_array)
    
    # storing all image data in numpy array
    test_data_array = np.array(image_arrays)

    return test_data_array

# %%
# Creating path
temp_test_dir = os.path.join(balanced_test_dir, "test_temp")

# Copying data
# dest = shutil.copytree(imbalanced_test_dir + "/" + "test", temp_test_dir)

# %%
# Load the test data and labels
test_data = load_test_data(temp_test_dir, image_size)

# Normalize the data if necessary (e.g., if you used normalization during training)
test_data = test_data / 255.0

# %%
# Loading true labels from validation path
true_labels = val_ds_imb.classes

# Predict the test data using the model
pred_imb = model.predict(test_data)

# Convert predicted probabilities to class labels (the index of the highest probability)
pred_labels = np.argmax(pred_imb, axis=-1)


# compute the confusion matrix
cm_imb = confusion_matrix(true_labels, pred_labels)

# class names
class_names = list(val_ds_imb.class_indices.keys())

# plot the confusion matrix
fig, ax = plt.subplots(figsize=(5, 5))  # Increase the size of the figure
cm_viz = ConfusionMatrixDisplay(confusion_matrix=cm_imb, display_labels=class_names)
cm_viz.plot(ax=ax, cmap=cm_funkyish, xticks_rotation='vertical')
ax.grid(False)
plt.show()

sns.set(font_scale=1.5)
report = classification_report(true_labels, pred_labels, target_names=class_names, output_dict=True)
df_report = pd.DataFrame(report).transpose()

# report as a dataframe
print(df_report)
# Out:
# 18/18 [==============================] - 4s 214ms/step
#               precision    recall  f1-score     support
# cloudy         0.977941  0.886667  0.930070  150.000000
# desert         0.884298  0.981651  0.930435  109.000000
# green_area     0.993289  0.986667  0.989967  150.000000
# water          0.967320  0.986667  0.976898  150.000000
# accuracy       0.958855  0.958855  0.958855    0.958855
# macro avg      0.955712  0.960413  0.956842  559.000000
# weighted avg   0.960950  0.958855  0.958779  559.000000

# %%
# Adapted from @isi_mube (Github)
for i in range(3):
    print(f"Example No {i}:", "\n")
    rand_img_dir = np.random.choice(os.listdir(imbalanced_test_dir))
    img_path = os.path.join(imbalanced_test_dir, rand_img_dir)

    img = Image.open(img_path)
    plt.imshow(img)
    plt.axis('off') 
    plt.title(f"{rand_img_dir}", fontsize = 10)
    plt.show()

    # load and preprocess the image
    img = image.load_img(img_path, target_size=(256,256))
    img_array = np.expand_dims(image.img_to_array(img), axis=0)

    # predictions
    predictions = model.predict(img_array)
    class_idx = np.argmax(predictions[0])  # class with highest probability
    class_prob = predictions[0][class_idx]

    # class label and confidence
    class_label = {v: k for k, v in train_ds_imb.class_indices.items()}[class_idx]
    print(f"The model predicts this image as: {class_label} with {class_prob*100:.2f}% confidence", "\n")
# Out:
# Example No 0:
# 1/1 [==============================] - 0s 37ms/step
# The model predicts this image as: green_area with 100.00% confidence
#
# Example No 1:
# 1/1 [==============================] - 0s 33ms/step
# The model predicts this image as: desert with 100.00% confidence
#
# Example No 2:
# 1/1 [==============================] - 0s 32ms/step
# The model predicts this image as: water with 100.00% confidence

# %% [markdown]
# ## <a id = 8.3></a><font color="lightseagreen">8.3 Running Model With Balanced Set<font>

# %% [markdown]
# ### <font color="lightseagreen">- Setting Up<font>

# %%
# Making sure model training will start from scratch
keras.backend.clear_session()

# %%
train_dir_bal = os.path.join(os.getcwd(), "data_balance/train")
val_dir_bal = os.path.join(os.getcwd(), "data_balance/valid")

# %%
train_bal_ds = datagen.flow_from_directory(
    train_dir_bal,
    seed=400,
    target_size=image_size,
    batch_size=batch_size,
    class_mode="categorical"
)

val_bal_ds = datagen.flow_from_directory(
    val_dir_bal,
    seed=400,
    target_size=image_size,
    batch_size=batch_size,
    class_mode="categorical",
)
# Out:
# Found 3496 images belonging to 4 classes.
# Found 436 images belonging to 4 classes.

# %%
model = make_model(input_shape=image_size + (3,))

# %%
model.compile(
    optimizer=keras.optimizers.Adamax(learning_rate=0.001),
    loss="categorical_crossentropy",
    metrics=["accuracy"],
)

# %%
step_size_btrain = train_bal_ds.n//train_bal_ds.batch_size
step_size_bval = val_bal_ds.n//val_bal_ds.batch_size

callbacks = [
    keras.callbacks.ModelCheckpoint("data_balance/epochs_bal_base_rep/save_at_{epoch}.keras")
]

# %% [markdown]
# ### <font color="lightseagreen">- Training & Evaluation<font>

# %%
hist = model.fit(
    train_bal_ds, 
    epochs=50,
    steps_per_epoch = step_size_btrain,
    validation_data=val_bal_ds,
    validation_steps = step_size_bval,
    callbacks = callbacks
)

cell_done()
# Out:
# Epoch 1/50
# 27/27 [==============================] - 134s 5s/step - loss: 0.6777 - accuracy: 0.6502 - val_loss: 0.4624 - val_accuracy: 0.7083
# Epoch 2/50
# 27/27 [==============================] - 131s 5s/step - loss: 0.3971 - accuracy: 0.8254 - val_loss: 0.3371 - val_accuracy: 0.8594
# Epoch 3/50
# 27/27 [==============================] - 131s 5s/step - loss: 0.3617 - accuracy: 0.8465 - val_loss: 0.4094 - val_accuracy: 0.8229
# Epoch 4/50
# 27/27 [==============================] - 133s 5s/step - loss: 0.3413 - accuracy: 0.8550 - val_loss: 0.3366 - val_accuracy: 0.8646
# Epoch 5/50
# 27/27 [==============================] - 130s 5s/step - loss: 0.3261 - accuracy: 0.8670 - val_loss: 0.3119 - val_accuracy: 0.8672
# Epoch 6/50
# 27/27 [==============================] - 130s 5s/step - loss: 0.3235 - accuracy: 0.8726 - val_loss: 0.3022 - val_accuracy: 0.8854
# Epoch 7/50
# 27/27 [==============================] - 130s 5s/step - loss: 0.2967 - accuracy: 0.8821 - val_loss: 0.2886 - val_accuracy: 0.8776
# Epoch 8/50
# 27/27 [==============================] - 130s 5s/step - loss: 0.3083 - accuracy: 0.8702 - val_loss: 0.2687 - val_accuracy: 0.9010
# Epoch 9/50
# 27/27 [==============================] - 130s 5s/step - loss: 0.3067 - accuracy: 0.8753 - val_loss: 0.2967 - val_accuracy: 0.8802
# Epoch 10/50
# 27/27 [==============================] - 131s 5s/step - loss: 0.2874 - accuracy: 0.8866 - val_loss: 0.2833 - val_accuracy: 0.8776
# Epoch 11/50
# 27/27 [==============================] - 138s 5s/step - loss: 0.3223 - accuracy: 0.8667 - val_loss: 0.2866 - val_accuracy: 0.8828
# Epoch 12/50
# 27/27 [==============================] - 136s 5s/step - loss: 0.2815 - accuracy: 0.8851 - val_loss: 0.3382 - val_accuracy: 0.8385
# Epoch 13/50
# 27/27 [==============================] - 130s 5s/step - loss: 0.2749 - accuracy: 0.8866 - val_loss: 0.2724 - val_accuracy: 0.8906
# Epoch 14/50
# 27/27 [==============================] - 130s 5s/step - loss: 0.2693 - accuracy: 0.8901 - val_loss: 0.2638 - val_accuracy: 0.9036
# Epoch 15/50
# 27/27 [==============================] - 131s 5s/step - loss: 0.2600 - accuracy: 0.8925 - val_loss: 0.2437 - val_accuracy: 0.9062
# Epoch 16/50
# 27/27 [==============================] - 132s 5s/step - loss: 0.2694 - accuracy: 0.8842 - val_loss: 0.2468 - val_accuracy: 0.9010
# Epoch 17/50
# 27/27 [==============================] - 135s 5s/step - loss: 0.2341 - accuracy: 0.8999 - val_loss: 0.2401 - val_accuracy: 0.9036
# Epoch 18/50
# 27/27 [==============================] - 142s 5s/step - loss: 0.2417 - accuracy: 0.9034 - val_loss: 0.2481 - val_accuracy: 0.8984
# Epoch 19/50
# 27/27 [==============================] - 138s 5s/step - loss: 0.2335 - accuracy: 0.9065 - val_loss: 0.2392 - val_accuracy: 0.9219
# Epoch 20/50
# 27/27 [==============================] - 139s 5s/step - loss: 0.2194 - accuracy: 0.9083 - val_loss: 0.1800 - val_accuracy: 0.9167
# Epoch 21/50
# 27/27 [==============================] - 140s 5s/step - loss: 0.2182 - accuracy: 0.9106 - val_loss: 0.1726 - val_accuracy: 0.9375
# Epoch 22/50
# 27/27 [==============================] - 139s 5s/step - loss: 0.1801 - accuracy: 0.9329 - val_loss: 0.2107 - val_accuracy: 0.9167
# Epoch 23/50
# 27/27 [==============================] - 138s 5s/step - loss: 0.1825 - accuracy: 0.9302 - val_loss: 0.2398 - val_accuracy: 0.9193
# Epoch 24/50
# 27/27 [==============================] - 141s 5s/step - loss: 0.1825 - accuracy: 0.9265 - val_loss: 0.2209 - val_accuracy: 0.9193
# Epoch 25/50
# 27/27 [==============================] - 138s 5s/step - loss: 0.1968 - accuracy: 0.9213 - val_loss: 0.1579 - val_accuracy: 0.9505
# Epoch 26/50
# 27/27 [==============================] - 138s 5s/step - loss: 0.2121 - accuracy: 0.9192 - val_loss: 0.2090 - val_accuracy: 0.9219
# Epoch 27/50
# 27/27 [==============================] - 138s 5s/step - loss: 0.1631 - accuracy: 0.9382 - val_loss: 0.1400 - val_accuracy: 0.9479
# Epoch 28/50
# 27/27 [==============================] - 137s 5s/step - loss: 0.1402 - accuracy: 0.9486 - val_loss: 0.1410 - val_accuracy: 0.9583
# Epoch 29/50
# 27/27 [==============================] - 138s 5s/step - loss: 0.1532 - accuracy: 0.9421 - val_loss: 0.1890 - val_accuracy: 0.9375
# Epoch 30/50
# 27/27 [==============================] - 138s 5s/step - loss: 0.1596 - accuracy: 0.9391 - val_loss: 0.1522 - val_accuracy: 0.9531
# Epoch 31/50
# 27/27 [==============================] - 163s 6s/step - loss: 0.1437 - accuracy: 0.9436 - val_loss: 0.1550 - val_accuracy: 0.9505
# Epoch 32/50
# 27/27 [==============================] - 144s 5s/step - loss: 0.1400 - accuracy: 0.9480 - val_loss: 0.1413 - val_accuracy: 0.9583
# Epoch 33/50
# 27/27 [==============================] - 146s 5s/step - loss: 0.1277 - accuracy: 0.9531 - val_loss: 0.1628 - val_accuracy: 0.9193
# Epoch 34/50
# 27/27 [==============================] - 149s 5s/step - loss: 0.1324 - accuracy: 0.9492 - val_loss: 0.1369 - val_accuracy: 0.9427
# Epoch 35/50
# 27/27 [==============================] - 160s 6s/step - loss: 0.1492 - accuracy: 0.9433 - val_loss: 0.1828 - val_accuracy: 0.9349
# Epoch 36/50
# 27/27 [==============================] - 160s 6s/step - loss: 0.1323 - accuracy: 0.9534 - val_loss: 0.1225 - val_accuracy: 0.9714
# Epoch 37/50
# 27/27 [==============================] - 162s 6s/step - loss: 0.1318 - accuracy: 0.9531 - val_loss: 0.1455 - val_accuracy: 0.9557
# Epoch 38/50
# 27/27 [==============================] - 164s 6s/step - loss: 0.1430 - accuracy: 0.9445 - val_loss: 0.1331 - val_accuracy: 0.9583
# Epoch 39/50
# 27/27 [==============================] - 163s 6s/step - loss: 0.1076 - accuracy: 0.9605 - val_loss: 0.1281 - val_accuracy: 0.9531
# Epoch 40/50
# 27/27 [==============================] - 167s 6s/step - loss: 0.1156 - accuracy: 0.9580 - val_loss: 0.1183 - val_accuracy: 0.9635
# Epoch 41/50
# 27/27 [==============================] - 157s 6s/step - loss: 0.1220 - accuracy: 0.9572 - val_loss: 0.1639 - val_accuracy: 0.9479
# Epoch 42/50
# 27/27 [==============================] - 158s 6s/step - loss: 0.1335 - accuracy: 0.9507 - val_loss: 0.0948 - val_accuracy: 0.9661
# Epoch 43/50
# 27/27 [==============================] - 156s 6s/step - loss: 0.1112 - accuracy: 0.9552 - val_loss: 0.1413 - val_accuracy: 0.9401
# Epoch 44/50
# 27/27 [==============================] - 157s 6s/step - loss: 0.1117 - accuracy: 0.9596 - val_loss: 0.1345 - val_accuracy: 0.9688
# Epoch 45/50
# 27/27 [==============================] - 149s 5s/step - loss: 0.1478 - accuracy: 0.9418 - val_loss: 0.1029 - val_accuracy: 0.9583
# Epoch 46/50
# 27/27 [==============================] - 140s 5s/step - loss: 0.0931 - accuracy: 0.9670 - val_loss: 0.0587 - val_accuracy: 0.9792
# Epoch 47/50
# 27/27 [==============================] - 141s 5s/step - loss: 0.0790 - accuracy: 0.9762 - val_loss: 0.0794 - val_accuracy: 0.9792
# Epoch 48/50
# 27/27 [==============================] - 140s 5s/step - loss: 0.0914 - accuracy: 0.9679 - val_loss: 0.0963 - val_accuracy: 0.9714
# Epoch 49/50
# 27/27 [==============================] - 141s 5s/step - loss: 0.1600 - accuracy: 0.9371 - val_loss: 0.1421 - val_accuracy: 0.9401
# Epoch 50/50
# 27/27 [==============================] - 152s 6s/step - loss: 0.1173 - accuracy: 0.9578 - val_loss: 0.0820 - val_accuracy: 0.9740

# %%
# # to fix facecolor that turned gray for some reason https://stackoverflow.com/questions/4581504/how-to-set-opacity-of-background-colour-of-graph-with-matplotlib#:~:text=If%20you%20want%20to%20make,of%20all%20facecolors%20to%200%25.
# plt.rcParams.update({
#     "figure.facecolor":  (1.0, 0.0, 0.0, 0.0),  # red   with alpha = 30%
#     "axes.facecolor":    (0.0, 1.0, 0.0, 0.0),  # green with alpha = 50%
#     "savefig.facecolor": (0.0, 0.0, 1.0, 0.0),  # blue  with alpha = 20%
#     "legend.facecolor": "white"
# })

# %%
balanced_hist_df = pd.DataFrame(hist.history)
balanced_hist_df.to_csv("data_balance/base_balanced_scores.csv", index = 0)

# %%
balanced_hist_df = pd.read_csv("data_balance/base_balanced_scores.csv")

# %%
fig = plt.figure(figsize = (7,5))
plt.plot(balanced_hist_df["accuracy"], color="mediumorchid", label="accuracy")
plt.plot(balanced_hist_df["val_accuracy"], color="springgreen", label="val_accuracy")
fig.suptitle("Accuracy - Balanced Data", fontsize=17)
plt.ylim(0, 1)
plt.legend(loc="lower right")
plt.show()

# %%
fig = plt.figure(figsize = (7,5))
plt.plot(hist.history["loss"], color="mediumorchid", label="loss")
plt.plot(hist.history["val_loss"], color="springgreen", label="val_loss")
fig.suptitle("Loss - Balanced Data", fontsize=17)
plt.ylim(0, 1)
plt.legend(loc="upper right")
plt.show()

# %% [markdown]
# ### <font color="lightseagreen">- Testing Against Unseen Data (test set)<font>

# %%
# Best Epoch is 47 - Highest accuracy, least difference between loss and val_loss. Accuracy and val_accuracy practically identical
checkpoint_path_base_bal = os.path.join(data_balance, "epochs_bal_base_rep", "save_at_47.keras")
model.load_weights(checkpoint_path_base_bal)
# Out:
# WARNING:absl:Skipping variable loading for optimizer 'Adamax', because it has 1 variables whereas the saved optimizer has 29 variables.

# %%
# Creating customized colormap for the confusion matrix
colors = [[0/255, 250/255, 154/255], [186/255, 85/255, 211/255]] # first color is MediumSpringGreen, last is MediumOrchid
cm_funky = LinearSegmentedColormap.from_list(
        "Custom", colors, N=256, gamma = 2)
# mat = np.indices((10,10))[1]
# plt.imshow(mat, cmap=cm)
# plt.show()

# %%
# Creating path
bal_test_temp = os.path.join(balanced_test_dir, "test_temp")

# Copying data
# dest = shutil.copytree(balanced_test_dir + "/" + "test", bal_test_temp)

# %%
# Load the test data and labels
test_data = load_test_data(bal_test_temp, image_size)

# Normalize the data if necessary (e.g., if you used normalization during training)
test_data = test_data / 255.0

# %%
# Loading true labels from validation path
true_labels = val_bal_ds.classes

# Predict the test data using the model
pred_bal = model.predict(test_data)

# Convert predicted probabilities to class labels (the index of the highest probability)
pred_labels = np.argmax(pred_bal, axis=-1)

# compute the confusion matrix
cm_bal = confusion_matrix(true_labels, pred_labels)

# class names
class_names = list(val_bal_ds.class_indices.keys())

# plot the confusion matrix
fig, ax = plt.subplots(figsize=(5, 5))  # Increase the size of the figure
cm_viz = ConfusionMatrixDisplay(confusion_matrix=cm_imb, display_labels=class_names)
cm_viz.plot(ax=ax, cmap=cm_funky, xticks_rotation='vertical')
ax.grid(False)
plt.show()

sns.set(font_scale=1.5)
report = classification_report(true_labels, pred_labels, target_names=class_names, output_dict=True)
df_report = pd.DataFrame(report).transpose()

# report as a dataframe
print(df_report)
# Out:
# 14/14 [==============================] - 3s 214ms/step
#               precision    recall  f1-score     support
# cloudy         0.981308  0.963303  0.972222  109.000000
# desert         0.981818  0.990826  0.986301  109.000000
# green_area     0.981982  1.000000  0.990909  109.000000
# water          0.990741  0.981651  0.986175  109.000000
# accuracy       0.983945  0.983945  0.983945    0.983945
# macro avg      0.983962  0.983945  0.983902  436.000000
# weighted avg   0.983962  0.983945  0.983902  436.000000

# %%
for i in range(1, 4):
    print(f"Example No {i}:", "\n")
    rand_img_dir = np.random.choice(os.listdir(balanced_test_dir))
    img_path = os.path.join(balanced_test_dir, rand_img_dir)

    img = Image.open(img_path)
    plt.imshow(img)
    plt.axis('off') 
    plt.title(f"{rand_img_dir}", fontsize = 10)
    plt.show()

    # loading, processing image
    img = image.load_img(img_path, target_size=(256, 256))
    img_array = np.expand_dims(image.img_to_array(img), axis=0)

    # generating predictions
    predictions = model.predict(img_array)
    class_idx = np.argmax(predictions[0])
    class_prob = predictions[0][class_idx]

    # class label and confidence
    class_label = {v: k for k, v in train_ds_imb.class_indices.items()}[class_idx]
    print(f"The model classifies this image as: {class_label} with {class_prob*100:.2f}% confidence", "\n")
# Out:
# Example No 0:
# 1/1 [==============================] - 0s 33ms/step
# The model predicts this image as: cloudy with 100.00% confidence
#
# Example No 1:
# 1/1 [==============================] - 0s 33ms/step
# The model predicts this image as: cloudy with 100.00% confidence
#
# Example No 2:
# 1/1 [==============================] - 0s 33ms/step
# The model predicts this image as: green_area with 100.00% confidence

# %% [markdown]
# ## <a id = 8.4></a><font color="lightseagreen">8.4 Model Optimization<font>

# %%
# Function to augment image subsets, set up, compile and run model
# Epochs were set to a standard 35
def run_keras(train_dir, val_dir, callbacks_in_dir, batch_size=32, learning_rate=0.001, epochs=35):  # callbacks_in_dir should be a path in the format "data/epochs/save_at_{epoch}.keras"

    print("\n")  # to separate each session
    
    # loading data
    train_ds = datagen.flow_from_directory(
            train_dir_bal,
            seed=400,
            target_size=image_size,
            batch_size=batch_size,
            class_mode="categorical"
    )
    val_ds = datagen.flow_from_directory(
            val_dir_bal,
            seed=400,
            target_size=image_size,
            batch_size=batch_size,
            class_mode="categorical"
    )
    
    # setting up model
    model = make_model(input_shape=image_size + (3,))
        
    # compiling
    model.compile(
            optimizer=keras.optimizers.Adamax(learning_rate=learning_rate),
            loss="categorical_crossentropy",
            metrics=["accuracy"]
    )
        
    # Where should the callbacks (aka saved instances of the model per epoch) be saved 
    callbacks = [keras.callbacks.ModelCheckpoint(callbacks_in_dir)]
        
    # defining step sizes that will allow the model to run through all data points over each epoch
    step_size_train = train_ds.n//train_ds.batch_size
    step_size_val = val_ds.n//val_ds.batch_size
        
    # creating points of reference to keep track of sections in cell output
    print(" ", f"Epochs/scores for batch_size = {batch_size}")
        
    # running model
    hist = model.fit_generator(
            train_ds, 
            epochs=epochs,
            steps_per_epoch = step_size_train,
            validation_data=val_ds,
            validation_steps = step_size_val,
            callbacks = callbacks
    )
    
    print(" ", f"Finished for batch_size = {batch_size}")
            
    # saving scores history in .csv for easy access and visualisations potentially in later sessions
    balanced_hist_df = pd.DataFrame(hist.history)
    balanced_hist_df.to_csv(f"batch{batch_size}_lr{learning_rate}.csv", index = 0)
    
    # deleting session so keras doesn't just keep building up on knowledge already aquired
    keras.backend.clear_session()
    
    # to let the pc cool down a bit between each cycle in case the function is called in a loop
    time.sleep(180)

# %% [markdown]
# ### <font color="lightseagreen">- Optimizing Batch Size<font>

# %%
batch_sizes = [32, 64, 256, 300, 450]  # attempts to train the model on one batch failed as the kernal kept dying
callback_paths = []
epoch = "{epoch}"

for batch_size in batch_sizes:
    callback_paths.append(f"data_balance/epochs_bal_batch_{batch_size}/save_at_{epoch}.keras")
    
i = 0

for batch_size in batch_sizes:
    run_keras(train_dir_bal, val_dir_bal, callback_paths[i], batch_size=batch_size, epochs = 30)
    i += 1

# %%
# Out:
# Found 3496 images belonging to 4 classes.
# Found 436 images belonging to 4 classes.
#
#  Epochs/scores for batch_size = 450
# Epoch 1/2
# 7/7 [==============================] - 255s 37s/step - loss: 1.4441 - accuracy: 0.3526
# Epoch 2/2
# 7/7 [==============================] - 183s 26s/step - loss: 0.7667 - accuracy: 0.6021
# Finished for batch_size = 450
# Found 3496 images belonging to 4 classes.
# Found 436 images belonging to 4 classes.
#
#  Epochs/scores for batch_size = 300
# Epoch 1/2
# 11/11 [==============================] - 127s 11s/step - loss: 0.9485 - accuracy: 0.5426 - val_loss: 0.4725 - val_accuracy: 0.7567
# Epoch 2/2
# 11/11 [==============================] - 125s 12s/step - loss: 0.4653 - accuracy: 0.7610 - val_loss: 0.4888 - val_accuracy: 0.7400
# Finished for batch_size = 300

# %% [markdown]
# ### <font color="lightseagreen">- Optimizing Learning Rate<font>
